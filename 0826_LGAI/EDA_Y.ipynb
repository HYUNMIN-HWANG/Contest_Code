# %%
# 분석용 라이브러리
import numpy as np
import pandas as pd

# 시각화 라이브러리
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataPath = 'D:\\Data\\LGAI_AutoDriveSensors\\'

#import train and test CSV files
train = pd.read_csv(dataPath+'train.csv')

# %%
train.iloc[:,57:].describe()
# Out:
#                Y_01          Y_02          Y_03          Y_04          Y_05  \
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean       1.353814      1.057267      1.014002     13.621191     31.290467
# std        0.356223      0.386266      0.361492      2.686632      2.543222
# min        0.017000      0.007000      0.017000     -0.331000     18.589000
# 25%        1.127500      0.793000      0.769000     11.822000     29.768000
# 50%        1.349000      1.044000      0.998000     13.837000     31.710000
# 75%        1.576000      1.300000      1.239000     15.626000     33.184000
# max        4.409000      3.998000      3.756000     98.794000     37.250000
#
#                Y_06          Y_07          Y_08          Y_09          Y_10  \
# count  39607.000000  39607.000000  39607.000000  39607.000000  39607.000000
# mean      16.529382      3.155054    -26.294839    -26.308623    -22.400062
# ...

# %% [markdown]
# ---
# Y_04 평균 신호대 잡음비

# %%
Y_04_df = train.loc[:,'Y_04']
Y_04_df.describe()
# Out:
# count    39607.000000
# mean        13.621191
# std          2.686632
# min         -0.331000
# 25%         11.822000
# 50%         13.837000
# 75%         15.626000
# max         98.794000
# Name: Y_04, dtype: float64

# %%
plt.figure(figsize=(30,5))
plt.plot(Y_04_df, label='Y_04') 
plt.legend()
plt.show()
# 너무 튀는 값이 있는데 불량인가??

# %% [markdown]
# ---
# Y_05 안테나 Gain 평균 각도2

# %%
Y_05_df = train.loc[:,'Y_05']
Y_05_df.describe()
# Out:
# count    39607.000000
# mean        31.290467
# std          2.543222
# min         18.589000
# 25%         29.768000
# 50%         31.710000
# 75%         33.184000
# max         37.250000
# Name: Y_05, dtype: float64

# %%
plt.figure(figsize=(30,5))
plt.plot(Y_05_df, label='Y_05') 
plt.legend()
plt.show()

# %% [markdown]
# ---
# Y_06 신호대 잡음비  (각도1)

# %%
Y_06_df = train.loc[:,'Y_06']
Y_06_df.describe()
# Out:
# count    39607.000000
# mean        16.529382
# std          1.893014
# min        -19.963000
# 25%         16.146000
# 50%         16.694000
# 75%         17.164000
# max         18.998000
# Name: Y_06, dtype: float64

# %%
plt.figure(figsize=(30,5))
plt.plot(Y_06_df, label='Y_06') 
plt.legend()
plt.show()
# 너무 튀는 값이 있는데 불량인가??

# %% [markdown]
# ---
# Y_07 안테나 Gain 평균

# %%
Y_07_df = train.loc[:,'Y_07']
Y_07_df.describe()
# Out:
# count    39607.000000
# mean         3.155054
# std          0.418940
# min          0.502000
# 25%          2.863000
# 50%          3.126000
# 75%          3.433500
# max          5.299000
# Name: Y_07, dtype: float64

# %%
plt.figure(figsize=(30,5))
plt.plot(Y_07_df, label='Y_07') 
plt.legend()
plt.show()

# %% [markdown]
# ---
# Y_08 ~ Y_10, Y_12 ~ Y_14 신호대 잡음비

# %%
Y_08_df = train.loc[:,'Y_08']
Y_09_df = train.loc[:,'Y_09']
Y_10_df = train.loc[:,'Y_10']
Y_12_df = train.loc[:,'Y_12']
Y_13_df = train.loc[:,'Y_13']
Y_14_df = train.loc[:,'Y_14']

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(6, 1, figsize=(30,10), sharex=True)

ax1.plot(Y_08_df)
ax1.set_ylabel('Y_08')
ax2.plot(Y_09_df)
ax2.set_ylabel('Y_09')
ax3.plot(Y_10_df)
ax3.set_ylabel('Y_10')
ax4.plot(Y_12_df)
ax4.set_ylabel('Y_12')
ax5.plot(Y_13_df)
ax5.set_ylabel('Y_13')
ax6.plot(Y_14_df)
ax6.set_ylabel('Y_14')

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ---
# Y_11 안테나 Gain 평균

# %%
Y_11_df = train.loc[:,'Y_11']
Y_11_df.describe()
# Out:
# count    39607.000000
# mean        24.325061
# std          0.830197
# min         19.844000
# 25%         23.836000
# 50%         24.420000
# 75%         24.911500
# max         26.703000
# Name: Y_11, dtype: float64

# %%
plt.figure(figsize=(30,5))
plt.plot(Y_11_df, label='Y_11') 
plt.legend()
plt.show()
